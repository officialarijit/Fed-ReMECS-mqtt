# %% [markdown]
# #  DEAP data rearrangements from .mat FILE
#
# # [Persion No, Video No., Channel No., EEG signal, Valence, Arousal]
#
# # [Persion No, Video No., Channel No., EDA signal, Valence, Arousal]
#
# # [Persion No, Video No., Channel No., RB signal, Valence, Arousal]

# %%
import pandas as pd
import numpy as np
import glob
import pickle
import scipy.io
import os

# %%
#=================================================
#Folder creation for rearranged DEAP dataset
#=================================================

datapath = '/DEAP Data/data_preprocessed_matlab/'

deapEEG = 'DEAP_eeg/' #Folder name
deapEDA = 'DEAP_eda/' #Folder name
deapRB = 'DEAP_respbelt/' #Folder name

pathEEG = os.path.join(datapath,deapEEG)
pathEDA = os.path.join(datapath,deapEDA)
pathRB = os.path.join(datapath,deapRB)
os.mkdir(pathEEG)
os.mkdir(pathEDA)
os.mkdir(pathRB)

# %%
#========================#
# EEG data rearrangement #
#========================#

eeg_channels = 32 #from 1 to 32
videos = 40 #number of videos 
participants = 32 #number of participants
print('==================================================================')
print('Re-arranged EEG data processing')
print('------------------------------------------------------------------')
print('[Persion No, Video No., Channel No., EEG signal, Valence, Arousal]')
print('==================================================================')


for p in range(0,participants): #particioants loop 
    print('-----------------------------------')
    print('Participant:',p+1)
    print('-----------------------------------')
    final_data = []
    if p <10:
        flpath = path+'s'+str(0)+str(p+1)+'.mat'
    else:
        flpath = path+'s'+str(p+1)+'.mat'
    df = scipy.io.loadmat(flpath)
    signal = df['data']
    emotion_labels = df['labels']
    for v in range(0,videos): #video loop
        print('------------------')
        print('Video Number:',v+1)
        print('------------------')
        signal_based_video = signal[v,:]
        for ch in range(0,eeg_channels): #eeg channels loop 
            final_data.append(np.concatenate(([p+1],[v+1],[ch+1],signal_based_video[ch,:],emotion_labels[v,[0,1]])))
    
    fdata= pd.DataFrame(final_data)
    fileName = pathEEG+str(p+1)+'_EEG.csv'
    fdata.to_csv(fileName, header=None, index=None)
# Out:
# ==================================================================
# Re-arranged EEG data processing
# ------------------------------------------------------------------
# [Persion No, Video No., Channel No., EEG signal, Valence, Arousal]
# ==================================================================
# -----------------------------------
# Participant: 1
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-f7265fb7b3c4> in <module>
#      35     fdata= pd.DataFrame(final_data)
#      36     fileName = pathEEG+str(p+1)+'_EEG.csv'
# ---> 37     fdata.to_csv(fileName, header=None, index=None)
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save(self)
#     326                 break
#     327
# --> 328             self._save_chunk(start_i, end_i)
#     329
#     330     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     360         )
#     361
# --> 362         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
#========================#
# EDA data rearrangement #
#========================#

eda_channels = [37] #channel no 37 according to DEAP dataset description
videos = 40 #number of videos 
participants = 32 #number of participants
print('==================================================================')
print('Re-arranged EDA data processing')
print('------------------------------------------------------------------')
print('[Persion No, Video No., Channel No., EDA signal, Valence, Arousal]')
print('==================================================================')


for p in range(0,participants): #particioants loop 
    print('-----------------------------------')
    print('Participant:',p+1)
    print('-----------------------------------')
    final_data = []
    if p <10:
        flpath = path+'s'+str(0)+str(p+1)+'.mat'
    else:
        flpath = path+'s'+str(p+1)+'.mat'
    df = scipy.io.loadmat(flpath)
    signal = df['data']
    emotion_labels = df['labels']
    for v in range(0,videos): #video loop
        print('------------------')
        print('Video Number:',v+1)
        print('------------------')
        signal_based_video = signal[v,:]
        for ch in eda_channels: #eeg channels loop 
            final_data.append(np.concatenate(([p+1],[v+1],[ch],signal_based_video[ch,:],emotion_labels[v,[0,1]])))
    
    fdata= pd.DataFrame(final_data)
    fileName = pathEDA+str(p+1)+'_EDA.csv'
    fdata.to_csv(fileName, header=None, index=None)
# Out:
# ==================================================================
# Re-arranged EDA data processing
# ------------------------------------------------------------------
# [Persion No, Video No., Channel No., EDA signal, Valence, Arousal]
# ==================================================================
# -----------------------------------
# Participant: 1
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 2
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 3
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 4
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 5
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 6
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 7
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-57796335d2f5> in <module>
#      33             final_data.append(np.concatenate(([p+1],[v+1],[ch],signal_based_video[ch,:],emotion_labels[v,[0,1]])))
#      34
# ---> 35     fdata= pd.DataFrame(final_data)
#      36     fileName = pathEDA+str(p+1)+'_EDA.csv'
#      37     fdata.to_csv(fileName, header=None, index=None)
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     519                             index = ibase.default_index(len(data))
#     520
# --> 521                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     522                 else:
#     523                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      81
#      82         # don't force copy because getting jammed in an ndarray anyway
# ---> 83         arrays = _homogenize(arrays, index, dtype)
#      84
#      85         columns = ensure_index(columns)
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     350                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     351             val = sanitize_array(
# --> 352                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     353             )
#     354
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     410
#     411     # extract ndarray or ExtensionArray, ensure we have no PandasArray
# --> 412     data = extract_array(data, extract_numpy=True)
#     413
#     414     # GH#846
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/construction.py in extract_array(obj, extract_numpy)
#     379     array([1, 2, 3])
#     380     """
# --> 381     if isinstance(obj, (ABCIndexClass, ABCSeries)):
#     382         obj = obj.array
#     383
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
# ---> 12         return getattr(inst, attr, "_typ") in comp
#      13
#      14     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
#=====================================#
# Respiratory Belt data rearrangement #
#=====================================#

rb_channels = [38] #channel no 38 according to DEAP dataset description
videos = 40 #number of videos 
participants = 32 #number of participants
print('===============================================================================')
print('Re-arranged data RB processing')
print('-------------------------------------------------------------------------------')
print('[Persion No, Video No., Channel No., Respiratory Belt signal, Valence, Arousal]')
print('===============================================================================')



for p in range(0,participants): #particioants loop 
    print('-----------------------------------')
    print('Participant:',p+1)
    print('-----------------------------------')
    final_data = []
    if p <10:
        flpath = path+'s'+str(0)+str(p+1)+'.mat'
    else:
        flpath = path+'s'+str(p+1)+'.mat'
    df = scipy.io.loadmat(flpath)
    signal = df['data']
    emotion_labels = df['labels']
    for v in range(0,videos): #video loop
        print('------------------')
        print('Video Number:',v+1)
        print('------------------')
        signal_based_video = signal[v,:]
        for ch in rb_channels: #eeg channels loop 
            final_data.append(np.concatenate(([p+1],[v+1],[ch],signal_based_video[ch,:],emotion_labels[v,[0,1]])))
    

    fdata= pd.DataFrame(final_data)
    fileName = pathRB+str(p+1)+'_RB.csv'
    fdata.to_csv(fileName, header=None, index=None)#save to CSV
# Out:
# ===============================================================================
# Re-arranged data RB processing
# -------------------------------------------------------------------------------
# [Persion No, Video No., Channel No., Respiratory Belt signal, Valence, Arousal]
# ===============================================================================
# -----------------------------------
# Participant: 1
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 2
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 3
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 4
# -----------------------------------
# ------------------
# Video Number: 1
# ------------------
# ------------------
# Video Number: 2
# ------------------
# ------------------
# Video Number: 3
# ------------------
# ------------------
# Video Number: 4
# ------------------
# ------------------
# Video Number: 5
# ------------------
# ------------------
# Video Number: 6
# ------------------
# ------------------
# Video Number: 7
# ------------------
# ------------------
# Video Number: 8
# ------------------
# ------------------
# Video Number: 9
# ------------------
# ------------------
# Video Number: 10
# ------------------
# ------------------
# Video Number: 11
# ------------------
# ------------------
# Video Number: 12
# ------------------
# ------------------
# Video Number: 13
# ------------------
# ------------------
# Video Number: 14
# ------------------
# ------------------
# Video Number: 15
# ------------------
# ------------------
# Video Number: 16
# ------------------
# ------------------
# Video Number: 17
# ------------------
# ------------------
# Video Number: 18
# ------------------
# ------------------
# Video Number: 19
# ------------------
# ------------------
# Video Number: 20
# ------------------
# ------------------
# Video Number: 21
# ------------------
# ------------------
# Video Number: 22
# ------------------
# ------------------
# Video Number: 23
# ------------------
# ------------------
# Video Number: 24
# ------------------
# ------------------
# Video Number: 25
# ------------------
# ------------------
# Video Number: 26
# ------------------
# ------------------
# Video Number: 27
# ------------------
# ------------------
# Video Number: 28
# ------------------
# ------------------
# Video Number: 29
# ------------------
# ------------------
# Video Number: 30
# ------------------
# ------------------
# Video Number: 31
# ------------------
# ------------------
# Video Number: 32
# ------------------
# ------------------
# Video Number: 33
# ------------------
# ------------------
# Video Number: 34
# ------------------
# ------------------
# Video Number: 35
# ------------------
# ------------------
# Video Number: 36
# ------------------
# ------------------
# Video Number: 37
# ------------------
# ------------------
# Video Number: 38
# ------------------
# ------------------
# Video Number: 39
# ------------------
# ------------------
# Video Number: 40
# ------------------
# -----------------------------------
# Participant: 5
# -----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-693d62a7eab2> in <module>
#      23     else:
#      24         flpath = path+'s'+str(p+1)+'.mat'
# ---> 25     df = scipy.io.loadmat(flpath)
#      26     signal = df['data']
#      27     emotion_labels = df['labels']
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     222     with _open_file_context(file_name, appendmat) as f:
#     223         MR, _ = mat_reader_factory(f, **kwargs)
# --> 224         matfile_dict = MR.get_variables(variable_names)
#     225
#     226     if mdict is not None:
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     331                 continue
#     332             try:
# --> 333                 res = self.read_var_array(hdr, process)
#     334             except MatReadError as err:
#     335                 warnings.warn(
#
# ~/anaconda3/envs/pySIO/lib/python3.6/site-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     291            `process`.
#     292         '''
# --> 293         return self._matrix_reader.array_from_header(header, process)
#     294
#     295     def get_variables(self, variable_names=None):
#
# KeyboardInterrupt:
